# %%
import pandas as pd
import numpy as np
import nltk

# %%
X_train=pd.read_csv('/home/hduser/Desktop/FundingProject/Data/train.csv')
X_test=pd.read_csv('/home/hduser/Desktop/FundingProject/Data/test.csv')

# %%
X_train.shape
# Out:
# (108129, 14)

# %%
y=X_train['final_status']

# %%
X_test.shape
# Out:
# (63465, 12)

# %%
X_train.head()
# Out:
#        project_id                                               name  \
# 0  kkst1451568084                                drawing for dollars
# 1  kkst1474482071  Sponsor Dereck Blackburn (Lostwars) Artist in ...
# 2   kkst183622197                                      Mr. Squiggles
# 3   kkst597742710                     Help me write my second novel.
# 4  kkst1913131122             Support casting my sculpture in bronze
#
#                                                 desc    goal  \
# 0  I like drawing pictures. and then i color them...    20.0
# 1  I, Dereck Blackburn will be taking upon an inc...   300.0
# 2  So I saw darkpony's successfully funded drawin...    30.0
# 3  Do your part to help out starving artists and ...   500.0
# 4  I'm nearing completion on a sculpture, current...  2000.0
#
#                                             keywords  disable_communication  \
# 0                                drawing-for-dollars                  False
# 1  sponsor-dereck-blackburn-lostwars-artist-in-re...                  False
# 2                                       mr-squiggles                  False
# 3                      help-me-write-my-second-novel                  False
# 4             support-casting-my-sculpture-in-bronze                  False
#
#   country currency    deadline  state_changed_at  created_at  launched_at  \
# 0      US      USD  1241333999        1241334017  1240600507   1240602723
# 1      US      USD  1242429000        1242432018  1240960224   1240975592
# 2      US      USD  1243027560        1243027818  1242163613   1242164398
# 3      US      USD  1243555740        1243556121  1240963795   1240966730
# 4      US      USD  1243769880        1243770317  1241177914   1241180541
#
#    backers_count  final_status
# 0              3             1
# 1              2             0
# 2              0             0
# 3             18             1
# 4              1             0

# %%
X_test.head()
# Out:
#        project_id                                               name  \
# 0   kkst917493670                                          Bràthair.
# 1  kkst1664901914                                   THE SCREENWRITER
# 2   kkst925125077        The Hornets Nest the Fairmont Heights Story
# 3  kkst1427645275  BROTHERS Season 2 - Groundbreaking Transgender...
# 4  kkst1714249266                                 Blackdom the movie
#
#                                                 desc     goal  \
# 0  My first film, of many to come. Trying to purs...   7000.0
# 1  A young man that has earned his master's in sc...  35000.0
# 2  Film about a high school constructed for negro...  49500.0
# 3  The acclaimed series about a group of transgen...  40000.0
# 4  Blackdom's history offers  a new narrative tha...  20000.0
#
#                                             keywords  disable_communication  \
# 0                                           brathair                  False
# 1                                   the-screenwriter                  False
# 2        the-hornets-nest-the-fairmont-heights-story                  False
# 3  brothers-season-2-groundbreaking-transgender-male                  False
# 4                                 blackdom-the-movie                  False
#
#   country currency    deadline  state_changed_at  created_at  launched_at
# 0      US      USD  1449619185        1449619185  1446002581   1446159585
# 1      US      USD  1453435620        1453435620  1450297323   1450411620
# 2      US      USD  1451780700        1451780700  1448581356   1448672128
# 3      US      USD  1445021518        1445021530  1440966830   1442429518
# 4      US      USD  1462068840        1462068844  1455765276   1458334890

# %%
X_train.drop(['name','disable_communication','country','currency','backers_count','final_status'],axis=1,inplace=True)

# %%
X_test.drop(['name','disable_communication','country','currency'],axis=1,inplace=True)

# %%
print(X_train.shape)
print("------------------------\n")
print(X_test.shape)
# Out:
# (108129, 8)
# ------------------------
#
# (63465, 8)

# %%
X_train.head()
# Out:
#        project_id                                               desc    goal  \
# 0  kkst1451568084  I like drawing pictures. and then i color them...    20.0
# 1  kkst1474482071  I, Dereck Blackburn will be taking upon an inc...   300.0
# 2   kkst183622197  So I saw darkpony's successfully funded drawin...    30.0
# 3   kkst597742710  Do your part to help out starving artists and ...   500.0
# 4  kkst1913131122  I'm nearing completion on a sculpture, current...  2000.0
#
#                                             keywords    deadline  \
# 0                                drawing-for-dollars  1241333999
# 1  sponsor-dereck-blackburn-lostwars-artist-in-re...  1242429000
# 2                                       mr-squiggles  1243027560
# 3                      help-me-write-my-second-novel  1243555740
# 4             support-casting-my-sculpture-in-bronze  1243769880
#
#    state_changed_at  created_at  launched_at
# 0        1241334017  1240600507   1240602723
# 1        1242432018  1240960224   1240975592
# 2        1243027818  1242163613   1242164398
# 3        1243556121  1240963795   1240966730
# 4        1243770317  1241177914   1241180541

# %%
#import time

#unix_cols = ['deadline','state_changed_at','launched_at','created_at']

#for x in unix_cols:
#    X_train[x] = X_train[x].apply(lambda k: time.ctime(k))
#    X_test[x] = X_test[x].apply(lambda k: time.ctime(k))

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63465 entries, 0 to 63464
# Data columns (total 8 columns):
# project_id          63465 non-null object
# desc                63461 non-null object
# goal                63465 non-null float64
# keywords            63465 non-null object
# deadline            63465 non-null int64
# state_changed_at    63465 non-null int64
# created_at          63465 non-null int64
# launched_at         63465 non-null int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 3.9+ MB

# %%
print(X_train.iloc[0])
# Out:
# project_id                                             kkst1451568084
# desc                I like drawing pictures. and then i color them...
# goal                                                               20
# keywords                                          drawing-for-dollars
# deadline                                                   1241333999
# state_changed_at                                           1241334017
# created_at                                                 1240600507
# launched_at                                                1240602723
# Name: 0, dtype: object

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108129 entries, 0 to 108128
# Data columns (total 8 columns):
# project_id          108129 non-null object
# desc                108121 non-null object
# goal                108129 non-null float64
# keywords            108129 non-null object
# deadline            108129 non-null int64
# state_changed_at    108129 non-null int64
# created_at          108129 non-null int64
# launched_at         108129 non-null int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 6.6+ MB

# %%
X_train.head()
# Out:
#        project_id                                               desc    goal  \
# 0  kkst1451568084  I like drawing pictures. and then i color them...    20.0
# 1  kkst1474482071  I, Dereck Blackburn will be taking upon an inc...   300.0
# 2   kkst183622197  So I saw darkpony's successfully funded drawin...    30.0
# 3   kkst597742710  Do your part to help out starving artists and ...   500.0
# 4  kkst1913131122  I'm nearing completion on a sculpture, current...  2000.0
#
#                                             keywords    deadline  \
# 0                                drawing-for-dollars  1241333999
# 1  sponsor-dereck-blackburn-lostwars-artist-in-re...  1242429000
# 2                                       mr-squiggles  1243027560
# 3                      help-me-write-my-second-novel  1243555740
# 4             support-casting-my-sculpture-in-bronze  1243769880
#
#    state_changed_at  created_at  launched_at
# 0        1241334017  1240600507   1240602723
# 1        1242432018  1240960224   1240975592
# 2        1243027818  1242163613   1242164398
# 3        1243556121  1240963795   1240966730
# 4        1243770317  1241177914   1241180541

# %%
X_test.head()
# Out:
#        project_id                                               desc     goal  \
# 0   kkst917493670  My first film, of many to come. Trying to purs...   7000.0
# 1  kkst1664901914  A young man that has earned his master's in sc...  35000.0
# 2   kkst925125077  Film about a high school constructed for negro...  49500.0
# 3  kkst1427645275  The acclaimed series about a group of transgen...  40000.0
# 4  kkst1714249266  Blackdom's history offers  a new narrative tha...  20000.0
#
#                                             keywords    deadline  \
# 0                                           brathair  1449619185
# 1                                   the-screenwriter  1453435620
# 2        the-hornets-nest-the-fairmont-heights-story  1451780700
# 3  brothers-season-2-groundbreaking-transgender-male  1445021518
# 4                                 blackdom-the-movie  1462068840
#
#    state_changed_at  created_at  launched_at
# 0        1449619185  1446002581   1446159585
# 1        1453435620  1450297323   1450411620
# 2        1451780700  1448581356   1448672128
# 3        1445021530  1440966830   1442429518
# 4        1462068844  1455765276   1458334890

# %%
def combinedata():
    combined_X=X_train.append(X_test)
    #combined_X['desc']=combinedX['desc'].astype(str)
    combined_X['diff_creat_laun']=abs(combined_X['created_at']-combined_X['launched_at'])
    combined_X['diff_laun_status']=abs(combined_X['launched_at']-combined_X['state_changed_at'])
    combined_X['diff_status_dead']=(combined_X['state_changed_at']-combined_X['deadline'])
    print("Shape of total data",combined_X.shape)
    return combined_X

# %%
combinedX=combinedata()
# Out:
# Shape of total data (171594, 11)

# %%
combinedX.drop(['created_at','launched_at','state_changed_at','deadline'],axis=1,inplace=True)

# %%
combinedX.head()
# Out:
#        project_id                                               desc    goal  \
# 0  kkst1451568084  I like drawing pictures. and then i color them...    20.0
# 1  kkst1474482071  I, Dereck Blackburn will be taking upon an inc...   300.0
# 2   kkst183622197  So I saw darkpony's successfully funded drawin...    30.0
# 3   kkst597742710  Do your part to help out starving artists and ...   500.0
# 4  kkst1913131122  I'm nearing completion on a sculpture, current...  2000.0
#
#                                             keywords  diff_creat_laun  \
# 0                                drawing-for-dollars             2216
# 1  sponsor-dereck-blackburn-lostwars-artist-in-re...            15368
# 2                                       mr-squiggles              785
# 3                      help-me-write-my-second-novel             2935
# 4             support-casting-my-sculpture-in-bronze             2627
#
#    diff_laun_status  diff_status_dead
# 0            731294                18
# 1           1456426              3018
# 2            863420               258
# 3           2589391               381
# 4           2589776               437

# %%
combinedX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 171594 entries, 0 to 63464
# Data columns (total 7 columns):
# project_id          171594 non-null object
# desc                171582 non-null object
# goal                171594 non-null float64
# keywords            171594 non-null object
# diff_creat_laun     171594 non-null int64
# diff_laun_status    171594 non-null int64
# diff_status_dead    171594 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 10.5+ MB

# %%
combinedX.isnull().any() #Null values check
# Out:
# project_id          False
# desc                 True
# goal                False
# keywords            False
# diff_creat_laun     False
# diff_laun_status    False
# diff_status_dead    False
# dtype: bool

# %%
df=combinedX.keywords

# %%
from nltk.corpus import stopwords
stop_words =(stopwords.words('english'))
stop_words.extend(['mr','my','the','a','may','also','zero','one','two','three','four','five','six','seven','eight','nine','ten','across','among','beside','however','yet','within'])

# %%
df2=df.copy()
df2=df2.str.lower().str.split('-')
df3=[] # Removing stop words
for item in df2:
    df3.append(list(set(item)-set(stop_words)))
df4=[] # removing alpha numeric words
for item in df3:
    df4.append([x for x in item if not any(c.isdigit() for c in x)])

# %%
df5=[]
for item in df4:
    df5.append([' '.join(item)])

# %%
df5
# Out:
# [['drawing dollars'],
#  ['blackburn residence illinois dereck sponsor artist kankakee lostwars'],
#  ['squiggles'],
#  ['help novel second write'],
#  ['support casting sculpture bronze'],
#  ['daily digest'],
#  ['free igoozex app iphone'],
#  ['faster car drive'],
#  ['lostles giant tinys'],
#  ['robot series choose adventure painting'],
#  ['anatomy book meltdown credibility'],
#  ['bit artist digital pixels inspired book drawings analog'],
#  ['hero game miniature board needs indie sculpted nerd'],
#  ['apps awesome iphone icons'],
#  ['anti help webseries make crime pilot violence'],
#  ['project pedal'],
#  ['frank party nyc magazine erotica issue'],
#  ['puzzles crossword'],
#  ['run blago show'],
#  ['become movie might'],
#  ['postcards'],
#  ['cookbook north'],
#  ['take trip watercolors anita postcard'],
#  ['art catalog nihilism decorative'],
#  ['unschooling movie'],
#  ['gamecamp athens'],
#  ['recording field smogr alert'],
#  ['black lp unbunnys edition strawberries limited'],
#  ['flying kebab'],
#  ['firewall sound'],
#  ['album help eighties make attractive womens new'],
#  ['offline wikipedia app iphone'],
#  ['bff'],
#  ['tweetsourcing'],
#  ['bit xbox live game hand pc painted iphone scrolling backgrounds adventure side arcade action'],
#  ['math learn innovating way children'],
#  ['help office us save'],
#  ['defense zombie app iphone'],
#  ['mind blow money'],
#  ['management gnash form cms source framework open'],
#  ['quixote fringe edinburgh dawn rides fest'],
#  ['van sleeping'],
#  ['asher put gareth tour'],
#  ['tarkovsky meeting andrei phase'],
#  ['mean feature produce film'],
#  ['metaphysical archaeology'],
#  ['design x cities'],
#  ['help prototype kindle led light'],
#  ['help world share finish book'],
#  ['sleep skeletons dont'],
#  ['album fusion rock new'],
#  ['completio street cd operation project lexi music'],
#  ['help weiss make ep allison new'],
#  ['mexican album debut caguama authentic make roc'],
#  ['uncle issue magazine'],
#  ['art cheap'],
#  ['balkans expedition peace'],
#  ['quest kinks reunite mans'],
#  ['childrens man adults charming book'],
#  ['sycophants help bring life tv pilot'],
#  ['det inches million'],
#  ['excepter series frkwys future'],
#  ['floaties lights hoosac river led'],
#  ['game beatz journey devs playground'],
#  ['ads ad series political total'],
#  ['times album next august release'],
#  ['video bit game strangeness adventure high action'],
#  ['laporte feature indiana film doc independent'],
#  [' ormolycka synttofs lp'],
#  ['recording boston slade demo sean'],
#  ['help us change greenlighted capitalism'],
#  ['man application iphone chair'],
#  ['man touring support music independent state'],
#  ['help us documentary let make tattoo'],
#  ['arise'],
#  ['help yes shwa make record'],
#  ['party pop orleans purpose new'],
#  ['lets world ever first around sail communi'],
#  ['dream jail goes'],
#  ['support ficly server project'],
#  ['customer people service'],
#  ['narobi mural project community mosaic youth'],
#  ['tribute old hundred'],
#  ['gimme childrens adoption shelter dog book'],
#  ['critical lovers darlings music unite'],
#  ['help ozy new complete market ep reigns l'],
#  ['scroll timesaving application custom email'],
#  ['issues redeemers'],
#  ['deliver debut album stand'],
#  ['back album laura york make meyer new'],
#  ['reform visual health explanation'],
#  ['april makes keep smith music indie record'],
#  ['studio start'],
#  ['livin dream'],
#  ['kebab fly'],
#  ['library underground'],
#  ['knitting lexie barnes lounge'],
#  ['mande get sessions malian cool make stuff'],
#  ['album help us third press'],
#  ['sce got game next documentary fighting'],
#  ['making landscape record television'],
#  ['reconstruction project rwanda'],
#  ['life giver lp'],
#  ['title working rocked fiction non book chicago'],
#  ['love pesipop back loves'],
#  ['get london coming'],
#  ['kids powering money seed music fundrais'],
#  ['lets room giant build theremin sized'],
#  ['art artloop back nyc get student'],
#  ['first album next made'],
#  ['reality illusion american dream documentar'],
#  ['feature film actually'],
#  ['become produce back album mari mack record'],
#  ['ghosts n super scrolling side'],
#  ['strangest tell science modern story time'],
#  ['creatures songs unusual'],
#  ['back help us get abroad home stranded'],
#  ['video like put web pilot dressing'],
#  ['devil cd edition limited release storm'],
#  ['album help tinyfolk record new'],
#  ['lords falcon city save'],
#  ['episode u another part'],
#  ['comical adventures animated series somewhat'],
#  ['history camp innovative kids non boring small'],
#  ['support translations miro subtitles'],
#  ['faces expressions mask'],
#  ['ga faust bring athens'],
#  ['masters'],
#  ['american graffiti battle artists go sderot'],
#  ['pub art nyc cafe'],
#  ['music baroque performing editions'],
#  ['lets find dogwalker write book'],
#  ['march movie'],
#  ['issue showpaper'],
#  ['audie learn different listen music kind'],
#  ['meditation art buddhist space'],
#  ['book sonnets red'],
#  ['help rubias norte complete las need del'],
#  ['vinyl florine edition limited ep'],
#  ['album journey bitchs next join b release'],
#  ['teach languages internet people radio'],
#  ['video times series life internet rules'],
#  ['film needs micro love budgeted'],
#  ['pops secret project monahan best indie kept r'],
#  ['mystery broadway rock musical roll melodies'],
#  ['crow help umbrella clear emergency records'],
#  ['art story book dictionary'],
#  ['monument mayors'],
#  ['albu solo withers gordon pre order cello new'],
#  ['online help us launch application new'],
#  ['test'],
#  ['kickstarter vs feltron'],
#  ['brower'],
#  ['held portraits ii matt phase facebook'],
#  ['series community village concert green'],
#  ['documentary dream change'],
#  ['video web concept new'],
#  ['dominican help coll book children luciastories'],
#  ['first time'],
#  ['album daniel makes debut williamson'],
#  ['artist help bone nyc brush project public'],
#  ['dick emoji'],
#  ['thousand copies world first wild music'],
#  ['game puzzle turba indie music'],
#  ['back help put road band'],
#  ['nepal experience'],
#  ['put jen tour woodhouse'],
#  ['watercolor christmas sale'],
#  ['building kit makerbeam source open'],
#  ['octopus mermaid fish'],
#  ['find warhols'],
#  ['ukulele goes berlin kellers helen'],
#  ['art education books indigo supplies youth'],
#  ['detroit project radio'],
#  ['living bipolar photoessay well book'],
#  ['reasons clare tour'],
#  ['heaux album show'],
#  ['math eternal story short regret'],
#  ['angola project'],
#  ['watercolor christmas give domain public'],
#  ['watercolor christmas princ copyleft cat'],
#  ['future experience fabrication'],
#  ['sunday taught bible schoo'],
#  ['going cd brothers finney release'],
#  ['free funds land film finishing'],
#  ['steve w sh inventing talk twilight cooper'],
#  ['misc dadaists costs gone wild'],
#  ['fund game help arcade brutal'],
#  ['fund bring life fantastical shifted'],
#  ['south website texas expansion'],
#  ['little create artists bird brass show'],
#  ['resonance retro contest game styled adventure e'],
#  ['video film la ever first music hollie'],
#  ['home game puzzle base independent'],
#  ['copy get writes robin book'],
#  ['festivals help film send freeport short'],
#  ['vitae circa fundage crowd record requests fu'],
#  ['patrick holiday puzzlefest blindauers'],
#  ['citizen ep icons new'],
#  ['animated gay pilot show bigfoot'],
#  ['sweatpants wearing'],
#  ['crazy feature fun horror dr bonesaw'],
#  ['fee deve igf misceallenous saturated dreamers'],
#  ['composer collective performer music new'],
#  ['album length debut full loom'],
#  ['need'],
#  ['bigquan video promotion project music'],
#  ['oil rival paintings small'],
#  ['art bringing advocacy hope world'],
#  ['birth james derek backer musical record'],
#  ['lets chan support expand e'],
#  ['records album sam heilig'],
#  ['printing showpaper'],
#  ['round detroi loveland premonitions inches'],
#  ['christmas dreams land dr c biplane'],
#  ['training design sculpture mosaic playground'],
#  ['weeks characters'],
#  ['art states keepers stories finders pie'],
#  ['preorder electronola ex get cd made custom'],
#  ['creating site promoting software source open'],
#  ['needs dolly push trolly'],
#  ['mysterious letters'],
#  ['pauses help first al need record'],
#  ['album tattle help record tales new'],
#  ['death recording album fight new'],
#  ['dffrnt new operation make ep kawnar'],
#  ['chance website take tuesday'],
#  ['webstream launch independent r chicago'],
#  ['arigato art domo roboto'],
#  ['instrument world greatest'],
#  ['bringing crossing borders music e'],
#  ['put dont twimote'],
#  ['lover first shotgun ep part'],
#  ['album affair make time xyz big'],
#  ['web era series'],
#  ['tanner novel makes graphic get jamie new'],
#  ['lab project san rescue antonio'],
#  ['hongs harry path perfection ne max'],
#  ['video spartan series life award winning new'],
#  ['cd making lemerts ava first'],
#  ['york topographical new'],
#  ['art installation mandalas interactive'],
#  ['julesworks take film fe santa treatment'],
#  ['vincis da dreams'],
#  ['cookbook soup bread'],
#  ['novel heaven cd goes'],
#  ['comed horror night punks throwback'],
#  ['video drama game freeq indie interactive radio'],
#  ['riot game comedy improv card laugh'],
#  ['zine turn wants anthology michelle'],
#  ['living odyssey throu year book line'],
#  ['science creation'],
#  ['architecture fund stripmall release new'],
#  ['mean ete people nothing'],
#  ['droplr'],
#  ['shore pastel sale prints jersey'],
#  ['herrin tyler wants needs fir'],
#  ['blue gets used sustainable kitabu bookstore'],
#  ['flying support kebab'],
#  ['onwards copenhagen brussels ben big'],
#  ['berkeley alumni uc literary anthology'],
#  ['film support short homecoming'],
#  ['inflatable dumpster ghost'],
#  ['sabbatical scott jason'],
#  ['falsebit sorts site elec hopeful news'],
#  ['bubblegum machine fusion'],
#  ['travel guide time survival'],
#  ['nobody round loveland til youre hates somebody'],
#  ['muralizer prints walls'],
#  ['art exhibiti store send candy show medicine'],
#  ['childrens wants robert jon hospital rock'],
#  ['finn miles next americana indie launch ep'],
#  ['miles thousands'],
#  ['film animated ar outsider short future'],
#  ['childrens book'],
#  ['fo survival zombie game indie zomband independent'],
#  ['table photo coffee book union'],
#  ['making happen otis'],
#  ['david passionate nayans novels ge spirituality'],
#  ['mothers cancer factors breast risk stor'],
#  ['remedy quarterly'],
#  ['w promoting film cross la country tour'],
#  ['party'],
#  ['sydney seasons'],
#  ['perception pits'],
#  ['documentary film sonicsgate'],
#  ['brainchildren record'],
#  ['series cities'],
#  ['mean araby records ne bear wrestles leaving'],
#  ['universal lights holiday'],
#  ['research markets seasonal heartland launch r'],
#  ['project umoja arts'],
#  ['live weekly circuit tech digest news'],
#  ['american debut needs standard ep release'],
#  ['feature film project wreck'],
#  ['feature length fatale movie'],
#  ['true man wishes story king'],
#  ['kim recording boekbinder solo'],
#  ['zachary table brown coffee project book'],
#  ['dancing story skeletons love'],
#  ['scooter dreams little hop artists red'],
#  ['shit lets happen shesays make'],
#  ['colorvision'],
#  ['help label career launch record'],
#  ['teacher evable bali un lear send'],
#  ['flit'],
#  ['brooklyn battle'],
#  ['nasty guide se good hold girls great'],
#  ['car pop revolutionary drawing perspective'],
#  ['ryan patrick ep'],
#  ['christian visions mmorpg'],
#  ['feature swallow film independent'],
#  ['fund van trailer nocturnal mes new'],
#  ['album kids trickster next chico mann'],
#  ['funds greasy rails grease mean needs'],
#  ['music concert syzygy new'],
#  ['dance film project'],
#  ['round loveland force powerful'],
#  ['portland adventures series book family'],
#  ['diet bacon'],
#  ['hand artcult recycling project lumber'],
#  ['sleep project family'],
#  ['art hudson valley incubator'],
#  ['throughout honor america women soldiers'],
#  ['become citizen city wonder'],
#  ['poetry variations lucia webcomics'],
#  ['hawaiis reefs cleaning'],
#  ['collaboration cd'],
#  ['world york today tomorrow painting new'],
#  ['gallery b ville exile'],
#  ['greta album new thump ger universal'],
#  ['book boy'],
#  ['old novel graphic get life ones breath'],
#  ['video game ri iran post election set'],
#  ['social label production company cause record'],
#  ['ba rail beyond boats leeward books band'],
#  ['detroit rise preserv music peaceballoon'],
#  ['harambe program reading'],
#  ['life vito acconci saved'],
#  ['quilty clover kc coriander needs release'],
#  ['poetry sweet'],
#  ['india tour xylopholks outreach'],
#  ['im'],
#  ['bringing telling writ stories classical music'],
#  ['pastel favorite vote painting jersey'],
#  ['album movement release part'],
#  ['whats building'],
#  ['peace project picture'],
#  ['join club multiplex book awesome'],
#  ['ryan diy artist vin join making pivotal hanna'],
#  ['needs love shop idea'],
#  ['kays hope debbie broken hearted'],
#  ['press'],
#  ['jse records unsigned best artists nycs'],
#  ['objects art living space public'],
#  ['tri walls tearing albritton mcclain'],
#  ['bach suites solo j complete cello'],
#  ['goddess multitasking'],
#  ['painting day'],
#  ['back album bring killers life q b bar'],
#  ['lets vapidus send road designs br'],
#  ['rew'],
#  ['print endangered project species'],
#  ['beyond books'],
#  ['republic fundraiser worldwide'],
#  ['decide lovers label music record'],
#  ['world tubing series'],
#  ['f sounds winter kick jams record new'],
#  ['death game help iphone kingdom'],
#  ['instal art publicly fruit funded strange public'],
#  ['thriller diary painter eloise made chicago'],
#  ['quarter pripyat later century'],
#  ['put season'],
#  ['age pretentious super making rockets'],
#  ['crowd painting giant'],
#  ['develop learn applications'],
#  ['free paintings everywhere original awesome'],
#  ['lp help get cool finish stuff'],
#  ['als playful thats always looking sexy calendar'],
#  ['round loveland peak inches'],
#  ['arab hip records hop league future'],
#  ['roed hamilton fund raiser'],
#  ['f kt countdown os first pro ep'],
#  ['film golden interdependent earrings'],
#  ['seeks artist exhibition bandwagon collaboration fu'],
#  ['music cuban future'],
#  ['video launching game association players new'],
#  ['auric shelter sculpture traveling'],
#  ['static genesis seeks funding android studio'],
#  ['lets album together comedy make'],
#  ['film stairs'],
#  ['art irart kids studio fundraiser'],
#  ['tongue every'],
#  ['presents transit'],
#  ['landscape unique paintings fe santa discoveri'],
#  ['research explore plast environmental mission'],
#  ['album debu'],
#  ['website dropping jaw podcasts biggest new'],
#  ['immortalized make get movie'],
#  ['white pennsylvania mile space home walk'],
#  ['rock alternative groundbreaking album'],
#  ['starting shirt shes company omg'],
#  ['album length full dylan movies'],
#  ['resurrection'],
#  ['infographics transit project hubcity'],
#  ['documentary delorean back'],
#  ['history christian faith dove dalian'],
#  ['deacon animal collective festival'],
#  ['music emay'],
#  ['first webseries living assistant'],
#  ['paranorma help horror hike finish short'],
#  ['weathervane philly fly'],
#  ['biz kidz weekly financial whiz quiz show l'],
#  ['saic catalog photography department'],
#  ['album bandits chappo send space tour'],
#  ['season series club dvd gold'],
#  ['primed mind priming'],
#  ['betacup fund prize'],
#  ['reanimation library coffer builder'],
#  ['seksu goes road tour asobi'],
#  ['debut album'],
#  ['recording ba put gift studio hot'],
#  ['stardom living dream road'],
#  ['defeaters vinyl repress travels'],
#  ['help ackwards hurry get bass sundance'],
#  ['samorian alcohol recordin john alphabet'],
#  ['empty art places innovative longer public'],
#  ['diy workshops support printing screen chicago'],
#  ['blue back makes record new'],
#  ['come website live finish'],
#  ['yes axelrods performance lawrence songs'],
#  ['live meet beyond master spiritual panac edge'],
#  ['video web series questions pilot big'],
#  ['artist bali composer residency'],
#  ['recording powder ep kegs new'],
#  ['life drawn comes colorido'],
#  ['lets alert crochet yurt home'],
#  ['film wesley du dumpling'],
#  ['couture haute armor agave series sculpture'],
#  ['planet unplugging earth greenoneday'],
#  ['haiti mission back got'],
#  ['wrong prosperthe live book'],
#  ['art sh together getting softwar business'],
#  ['makes along hour midnight come record'],
#  ['tonight schaeffer kids'],
#  ['diy chromatrope records jody indie schn music'],
#  ['margolis action torino potential'],
#  ['travel agency month store italian ice'],
#  ['lets louisiana together guide resource build'],
#  ['pinatalands scouts boy democracy'],
#  ['iphone audiogame'],
#  ['vetran record part new'],
#  ['darlene book wants give'],
#  ['usa something baumanns guitar jon tour'],
#  ['film change give makers stories'],
#  ['man project serve'],
#  ['creating wealth art beautyhealth'],
#  ['pres germain blvd des st'],
#  ['kindness story acts'],
#  ['exciting bring dopeless wish book new'],
#  ['interface architecture designing phase dia'],
#  ['produce oblivion series'],
#  ['daydream length full ever cd first jon cowarts'],
#  ['radles fourth making sara sol part'],
#  ['mama lchaim bring film life'],
#  ['decoration red loft fund'],
#  ['project clements kayle'],
#  ['help kids ep release new'],
#  ['potentially true obsessed story color'],
#  ['teen help band rock girl'],
#  ['book space monkey'],
#  ['tub sundance get'],
#  ['else psycliq get everywhere amazon itunes'],
#  ['africa debo returns band'],
#  ['exit film shoot clip big'],
#  ['illustrated variations lucia part'],
#  ['marissa makes youre record renee sing'],
#  ['reno stories real'],
#  ['africa south morocco search'],
#  ['publish box comics independent browns'],
#  ['postmedium orleans artists portfolios new'],
#  ['meet secret weapon fabs laurel'],
#  ['bads bigger'],
#  ['makin movie'],
#  ['artelexiabringing mexico casa'],
#  ['house shadows'],
#  ['movie love tv made aven henry'],
#  ['youtube olga circus kays'],
#  ['unseen lets online magazine sight new'],
#  ['william man burroughs'],
#  ['away tracks giving'],
#  ['maine winters bills heat scary'],
#  ['axematchcom measures exactly well musician'],
#  ['casting funding seeking life material business'],
#  ['close whore becoming virgin chronicles'],
#  ['poems days'],
#  ['video game ha life flashes might'],
#  ['totter teeter'],
#  ['befor bookbinder fold gone boldly'],
#  ['morning first records record pressing'],
#  ['ant'],
#  ['video jesse groove duke ewles music'],
#  ['project learning luz'],
#  ['shadows electronic support music release'],
#  ['buffalo album black albino doves new'],
#  ['produce mass time bison machine oleander'],
#  ['recite'],
#  ['rocket leave monu fly make moon'],
#  ['documentary story robbie ellis canvasman'],
#  ['cinema eurocrime begin documentary needs licen'],
#  ['liquisity platforming game indie liquid'],
#  ['fund lp pestilence peeesseye joy'],
#  ['fundraising adventure hunting'],
#  ['art saving mile time music'],
#  ['lp courage comp project consequence cu'],
#  ['musicians exchange cultural french inzinzac'],
#  ['documentary rock punk'],
#  ['supernatural first dramadey sorcery book'],
#  ['bleachbangsrock'],
#  ['peripheral episode city'],
#  ['n film work give indie highlight voice'],
#  ['years collect wow correspondence'],
#  ['thier vinyl help length full first susu release'],
#  ['kitchen andrew door lanier inside'],
#  ['album waterlaso wild new'],
#  ['quest build cars futurama'],
#  ['childrens mischief forest der book'],
#  ['album absynth third quintets project'],
#  ['times album debut life making'],
#  ['pulver film le driven documentary jens'],
#  ['hurricane houses victims'],
#  ['come sun'],
#  ['lisbon dolls'],
#  ['lets ill world make shape story b'],
#  ['japan trip dojo'],
#  ['album debut visionary make music stealth foxxs'],
#  ['food faces city edible revolution'],
#  ['album fabric life release part'],
#  ['album alfonso albums tellez project jr new'],
#  ['casualties unwoman album solo'],
#  ['slipping film short stone'],
#  ['create festival get next tickets last'],
#  ['comedy web se original band'],
#  ['comedy web series celery tv sketch'],
#  ['game roleplaying nostalgic rpg vastar'],
#  ['flojugglercom'],
#  ['feline frenzy'],
#  ['music sophomore record whisker'],
#  ['recording album ghana bust dream wunmis'],
#  ['human crow idea wolf peaceful'],
#  ['something help beautiful project atomica make'],
#  ['art inst look learn painting laugh'],
#  ['recipe storing easy nom bookmarking'],
#  ['art everybody get cheap'],
#  ['daily minute'],
#  ['video film digital woods hd'],
#  ['islands south sandwiche gentlemen'],
#  ['title feature film working project'],
#  ['thriller bizarre hatter mad'],
#  ['night stand survive'],
#  ['gallery showspace art party expo build music'],
#  ['history usa somatic archive natural'],
#  ['bait devils crap clowns hound'],
#  ['legend limbo el'],
#  ['dream'],
#  ['taxi mo bumpy drivers beijing ride'],
#  ['twitter favorite tweet avatar let paint'],
#  ['jog split cassette ibreathefur'],
#  ['cabin building'],
#  ['system'],
#  ['survival society'],
#  ['grows hackerspace brooklyn'],
#  ['birthchart'],
#  ['travel art nihon project sustainable'],
#  ['embarassment ian anderson project c'],
#  ['chicks creators zo web series star'],
#  ['secret open'],
#  ['recording w club sad book bastard doom'],
#  ['blue w inch widow b snooze'],
#  ['label share project ep record part'],
#  ['rebel promoting filmmakers emerging rebfest'],
#  ['girl guide b context'],
#  ['album terrible zontar spaceship finish'],
#  ['international help artist allen make vandever'],
#  ['comedy bugbaby misadventures horror'],
#  ['brain win learn seed seeds'],
#  ['horse project intarsia carousel'],
#  ['metropolitones prizes get cd record new'],
#  ['textile technology co printing lumi new'],
#  ['calmplex kickstart'],
#  ['patrol feature film length documentary base jaker'],
#  ['microfiction novel deathless graveyard greg'],
#  ['background thriving documentary matter'],
#  ['recording authors apology new'],
#  ['guide engineers startups valley silicon'],
#  ['ep album ians debut'],
#  ['artist indy west day coast tour shows'],
#  ['film project bound seattle'],
#  ['bomb poetry'],
#  ['album trances arc release new'],
#  ['n zoop point click hilarious ad future'],
#  ['album jonah look knights wants different new'],
#  ['japanese eating'],
#  ['narrative fugue game unfurling bonus'],
#  ['thousandaire associates party victory savior'],
#  ['instrumental ep rock darrens'],
#  ['candle doublecross holders kenneth nilson'],
#  ['documentary capture waves'],
#  ['deville happen make starring music'],
#  ['video live featuring bay songwri podcast'],
#  ['yo davis funkyband fabulous expose garrick'],
#  ['shelter fallout live celebrating year'],
#  ['thea w administration pushpush era arts new'],
#  ['illustrated print gopher goes'],
#  ['timber coming scrawled record soon new'],
#  ['sxsw goes bounce party block orleans music new'],
#  ['broadcast help buy van krisko caitlin band'],
#  ['coming real stories crying sex'],
#  ['coves headed lost sxsw'],
#  ['campaign marketing cubicide'],
#  ['sutra cannabis'],
#  ['robot disabled legs'],
#  ['bit amazing bring datapop artists'],
#  ['impel pixel photojournali project aspiring'],
#  ['sketching acamonchi city york new'],
#  ['turkish azeri american majeure force first'],
#  ['safer visibility bright diy bike night kits r'],
#  ['lost fiction reach urban youth'],
#  ['harvest filming hope national underground fe'],
#  ['train untitled movie'],
#  ['dunbar sxsw banned get sgt hobo'],
#  ['playborg photographer eternal story short'],
#  ['album chordials new'],
#  ['making hour record midnight'],
#  ['development stains funds grass'],
#  ['feature film hank time'],
#  ['ecny awards annual'],
#  ['lets album hounds recreate bush kate'],
#  ['flutes roots'],
#  ['muscular slams professional dystrophy wrestling'],
#  ['elephant asian conservation documentary'],
#  ['going mcclean dirty courtney curls'],
#  ['shortfilm fi vfx similo sci'],
#  ['help curse recor ctm finish mariner'],
#  ['game showc brings indie legendary kokoromi'],
#  ['comfortable cowboy cooking'],
#  ['fund exhibition hotel pink completion'],
#  ['found lost body mata hari head'],
#  ['vinyl editio leisurely kickstarter ep headband'],
#  ['ruled world artists'],
#  ['sxsw candler covers blog'],
#  ['feature film sci independent fi outpost'],
#  ['roar hear us newspaper literary'],
#  ['game ghos season legend loveland pre'],
#  ['international artist debut allen make vandever'],
#  ['alabama balthrop tour trust texas'],
#  ['vs andrew collective'],
#  ['garden comedy secret web mother series eves'],
#  ['launching vinyl label join record ambiti'],
#  ['health world ride'],
#  ['welker mary coming winter poems'],
#  ['ow beat cherry hollywood bomb time'],
#  ['rap'],
#  ['copy book toms name'],
#  ['album theres fork keep homespun pie'],
#  ['ghosts'],
#  ['brit bake ears cavalry indie ep'],
#  ['hymnal abolitionist'],
#  ['art simulation extreme challenge hugtime'],
#  ['watterson exploration dear ca cinematic'],
#  ['artist panhandler partnerships build outsiders'],
#  ['jcut purchasing labs hackerspace alpha'],
#  ['streeteats'],
#  ['reactor bussard building fusion source open'],
#  ['detroit city archiving rocks exploring motor'],
#  [''],
#  ['relentless together fou stand come'],
#  ['game gam evolved roleplaying design system'],
#  ['austin henrys get mpls need'],
#  [''],
#  ['making needs heroes frontier new'],
#  ['send flatstock fakedog sxsw'],
#  ['english series reads educational dvd ready'],
#  ['welker mary coming winter poems'],
#  ['broussard lelia former songs record new'],
#  [''],
#  ['quarter feature makes film orange'],
#  ['print rook magazine issue mad'],
#  ['promote fashion art ncp classical converge'],
#  ['mobile generation television music'],
#  ['ramos season jeff'],
#  ['send bikebike bici'],
#  ['totter teeter cartoon'],
#  ['post costs hidden production children'],
#  ['art help show support jen ones woman book'],
#  ['sitcom unconventi car pilot'],
#  ['presents akira exhibit toonseum'],
#  ['archives'],
#  ['intimate think look know people u'],
#  ['feature film independent baine'],
#  ['passion sincere film amour short'],
#  ['patrons arts monstrous'],
#  ['petal fire books'],
#  ['film pillowmaker animated'],
#  ['robot film pass giant act short puppet'],
#  ['project word publishing'],
#  ['help message iceland positive spread'],
#  ['oil van tour trees vegetable big'],
#  ['recording bach suites solo cello archguitar'],
#  ['pledg cd records timbre new'],
#  ['objectifier making make easy stuff'],
#  ['international festival music chicago movies'],
#  ['man happy documentary short'],
#  ['zombies vs humans source'],
#  ['warrior kochalka james pixeljam glorkian'],
#  ['pants musi heart songs wear'],
#  ['brou celtic harp cd marie sarah mullens new'],
#  ['manifestation stupidity ode mind'],
#  ['recording live equi another day needs earth'],
#  ['music video people hole'],
#  ['hall bayreuth burning concert reclaiming'],
#  ['sxsw touring expensive knew would'],
#  ['swings budzillus apple big'],
#  ['owl part mousing alphonse'],
#  ['album debut cellists inspired song folkfire'],
#  ['face short animated plain'],
#  ['people games'],
#  ['music visually inerpret organization'],
#  ['come true dreams'],
#  ['itunes name'],
#  ['funds film porkchop need indie dvd'],
#  ['f novel libertarian around hampshire set new'],
#  ['writer humor known semi send yoga well school'],
#  ['earth space photograph'],
#  ['game season loveland pre continued ghost inches'],
#  ['zombie conversational web series b comedic'],
#  ['creating flower csa farm sustainable nationwide'],
#  ['book project coffee adventures'],
#  ['francisco san fourplay'],
#  ['album debut ft hustluhs young yukm e release'],
#  ['handbook poetic pagan magicians'],
#  ['brazilian de jan series gay cariocas set rio'],
#  ['word vanishing'],
#  ['partners website sharewiththree women'],
#  ['rise fall spill popcorn ushers'],
#  ['canvas'],
#  ['invited journeys webseries sci fi'],
#  ['stuffer'],
#  ['debut album wolfs charlie'],
#  ['love best part'],
#  ['death beta full project race release'],
#  ['world campaign war setting dandd codex new'],
#  ['support glow artists'],
#  ['hip album conscious hop peace'],
#  ['provisional patent tess cooling system'],
#  ['send summit stc'],
#  ['album texodus'],
#  ['prints project wild mi book poems arts'],
#  ['solo acrophobe cd acoustic roub paul'],
#  ['history twhistory doomed forget'],
#  ['hip infused videogame rapstar hop heroes'],
#  ['starting professor seed planting busin e'],
#  ['antipledge'],
#  ['swimming film short away'],
#  ['casting kristin'],
#  ['monster help hungry child th eat supporting'],
#  ['driver'],
#  ['episodes ground'],
#  ['lamp spaceman little'],
#  ['create art public homeless'],
#  ['intercollegiate hackath first hacknyorg nycs'],
#  ['ever first cuban c bagpipers documenting'],
#  ['franz westervelts debut tenor cd schuber bryce'],
#  ['glitt festival marketing funding'],
#  ['beyond essays film damname fundraising p'],
#  ['album ike making joy new'],
#  ['elephant spooning society'],
#  ['phantoms make record fuzz'],
#  ['elbows novel window'],
#  ['blanklab road back get'],
#  ['electric car frankencar mile charge'],
#  ['sympathetic vibrations'],
#  ['virtual life second harlem enhancing e'],
#  ['dancer feiffer films'],
#  ['roslers recording booth arcade small'],
#  ['page movie yorktown kings donut makin'],
#  ['gent'],
#  ['chris churchills movie making'],
#  ['back zombie zo iphone fight fortress'],
#  ['preproduction saints siam slaves'],
#  ['heating proper system'],
#  ['novel graphic robot squid'],
#  ['video lerman ukulele plays ben music air'],
#  ['bit maps look like v world real cities'],
#  ['album gathering debut fundraiser strange'],
#  ['lecture short time different'],
#  ['ruach rock'],
#  ['help press heart muse tw tantrum'],
#  ['bye us general wants rock'],
#  ['pork chop night'],
#  ['make album anthony fiumano'],
#  ['repurposing elevat stored giant potential grain'],
#  ['launc help us fly grounded realityneeds'],
#  ['cross'],
#  ['team bot reapers battle finish'],
#  ['patch sheds novel epid growing light'],
#  ['fo feet old send year others'],
#  ['vinyl omnichords cross boar jenny record canada'],
#  ['range'],
#  ['hip singer moss vanessa pop development'],
#  ['quarter besides daniels dozen shots'],
#  ['gamers love code story'],
#  ['soft la loveland ghost inches inchermission'],
#  ['us tour mbird radio'],
#  ['game cadet adventure visua action'],
#  ['han hand film iconoclastic vision made'],
#  ['memory web reenactm series remember'],
#  ['research performance akabellas tour'],
#  ['album david eli country project'],
#  ['recording meis asia ep new'],
#  ['installments fox adventure cocky'],
#  ['help us pla lisa needs wings project ronsons new'],
#  ['recording artist country studio nashville music'],
#  ['narrative film men first boys'],
#  ['maps racers album electronic pop star night'],
#  ['art collaborative pastor project al music'],
#  ['finding fiction release set ready'],
#  ['hours want part'],
#  ['face film collaborative fixed short'],
#  ['harvest film filmmaking short kickstart'],
#  ['platinum vinyl committees disc get picture busy'],
#  ['help next record fund'],
#  ['noir film candy little hearts short neo'],
#  ['netherlands halstead help tour u jenee'],
#  ['bonjour felicity'],
#  ['ho west oh coast hi tour silver'],
#  ['fantasy project road mirrors urban'],
#  ['fence endangered wildlife side'],
#  ['album wants record choke word'],
#  ['novelty murals paintings'],
#  ['ras vin cd project kass untitled limited'],
#  ['finn huck jacques less cousteau'],
#  ['linquistics coll notebook viral music drawings'],
#  ['broadw film based patient short'],
#  ['people reality citizens show'],
#  ['feature happen double everything'],
#  ['worth minuti'],
#  ['album boxing possibilities lesso new'],
#  ['resurrection losing elliot religion p'],
#  ['satellites paintings'],
#  ['dark comedy visions love musical'],
#  ['build batmobile tv'],
#  ['tribeca film festival perdition sons'],
#  ['city send york sonicsgate screen new'],
#  ['twanger album lost twang'],
#  ['album creating sennas share dormant jon new'],
#  ['back fusbicome'],
#  ['travel art nihon project sustainable'],
#  ['life hawkes al eventful'],
#  ['olive dissection'],
#  ['music audio ergo sum'],
#  ['promote audien record release new'],
#  ['player cd records walking stilt mandolin'],
#  ['help records stumparumper survive'],
#  ['ipad audio midi mxnm'],
#  ['nyc finals accidentals send icca uga'],
#  ['play micros cd friday monk new'],
#  ['abou multimedia documentary project guarani'],
#  ['episodes condominance'],
#  ['short things stor body'],
#  ['hype eat heart honeysuckle'],
#  ['lets album blameshift togethe make sophomore'],
#  ['addicube'],
#  ['creating creative forces keep'],
#  ['survival younger scars story many g'],
#  ['documentary homegrown first right'],
#  ['explores stars feature investigative th'],
#  ['episode dramatic series pilot pioneer'],
#  ['better living chemistry film short'],
#  ['cds company start record summertime ready'],
#  ['house suh'],
#  ['true feature film based love sucks music'],
#  ['journey afterlife light'],
#  ['days revolutionary wheres spirit'],
#  ['film collaborative underground adam high'],
#  ['final peripheral city shoot pilot'],
#  ['years making urbansnake'],
#  ['posttv platform producing exhibiting new'],
#  ['loveland continues'],
#  ['album funding project waves heartbeater slow'],
#  ['promoting film irratio'],
#  ['route worlds mos en project easter island'],
#  ['album help field first mouses press'],
#  ['inaugural contemporaneous season'],
#  ['nights rock roll'],
#  ['affordable press setting'],
#  ['album step panaceas deserves program p new'],
#  ['comedy musical champion animated'],
#  ['lifetime paintings project'],
#  ['creating somthing wonderful start'],
#  ['mermaid little'],
#  ['clawdette feline cat story lov'],
#  ['game roleplaying design modern'],
#  ['saturday dollymentary exhibtion unbrid mfa'],
#  ['gets sale patients starting pre record'],
#  ['pixelpete'],
#  ['prometheus mo album burning double stop disk'],
#  ['multi land opportunity platform documentary'],
#  ['gypsy orleans folk rock th mobilizing show new'],
#  ['emmaus project'],
#  ['beauteous'],
#  ['novel pandemonia chronicles boys'],
#  ['open billy syko'],
#  ['christmas carol flexitoon sandy presents beckers'],
#  ['rooms collection stories short darkened'],
#  ['road bus get green'],
#  ['puff trailer iphone game'],
#  ['project'],
#  ['video hip palma hop music b'],
#  ['tobin origin spirito heather anthony record'],
#  ['craigslist diaries'],
#  ['end project summers shirt'],
#  ['river earth celebrations hudson pageant'],
#  ['ostrander funding film finish short'],
#  ['lets album happen sleep good make new'],
#  ['think spy suess dr blaire meets sees bears'],
#  ['goes artist sketchy gencon'],
#  ['live comic web series superhero book action'],
#  ['potentially true obsessed story color'],
#  ['solutions individuals good radio climate dirt'],
#  ['diy osloom electrom loom source open jacquard'],
#  ['better things said music stuff'],
#  ['rocky road'],
#  ['chronicle nightly bread dinners daily'],
#  ['aesthetic amplifying inspir refuge voice'],
#  ['celebrate fair film festival world day trade'],
#  ['album hel stole songs survived new'],
#  ['absurd comedy seriously let disorder'],
#  ['album beautiful dirty electrocution bunny titled'],
#  ['de trio europe diverse tour'],
#  ['success puzzle college solving boo'],
#  ['something jazz leo ferguson octet different'],
#  ['music electric car tour'],
#  ['dede cd'],
#  ['poetry brushing wing white projection build'],
#  ['dark comedy choice smoky derrick'],
#  ['building giant country studio renovation'],
#  ['snocap album debut summer ep release'],
#  ['paranormal seekers'],
#  ['bucks drawings'],
#  ['monitor hap de dizzy force make tour kind'],
#  ['ode jack'],
#  ['film shake short strawberry'],
#  ['musicking album made time new'],
#  ['noir garde novel hungry rats avant'],
#  ['found lost whistled language exploring'],
#  ['albu pauses help debut need record'],
#  ['waters fund film welcome festival gentle'],
#  ['apocalypse opera cd burning survive'],
#  ['cherokee street comes peoples annual'],
#  ['bites alligator wide launch open possibilit'],
#  ['de booty tour france troves'],
#  ['help cd emilio kickstarter record new'],
#  ['makeover urba online american series new'],
#  ['video colbert animated stephen'],
#  ['third project hour'],
#  ['secret youtube project'],
#  ['web series soul'],
#  ['afterlight feature film michael kelly'],
#  ['cyclops monster ollie'],
#  ['passage book nirvana'],
#  ['sellout minimum suzy bare'],
#  ['lets reality shu fatcamp make shos'],
#  ['bringing zealand collegiate singing male new'],
#  ['songs moonbears sleepytime stories'],
#  ['summer garden'],
#  ['art keeps work body wandering new'],
#  ['study written anthropos philos everyone'],
#  ['album mowz debut animated short'],
#  ['album abel dan get records new'],
#  ['funding film directors cut independent'],
#  ['lion tracking source open collars'],
#  ['prophetic navajo boy hu rainbow story'],
#  ['thesis film lars manuela rossis'],
#  ['knuckle independently film ballad produced brass'],
#  ['musicians presentations music'],
#  ['n loves die dawson rosario want right'],
#  ['f man mountain records presents peoples underwater'],
#  ['gallery'],
#  ['action time'],
#  ['whiskey romanced'],
#  ['dramatic web nyc school way comedic high'],
#  ['create publication back freedom'],
#  ['nothing star hurt story big'],
#  ['says sir'],
#  ['multi everglades art media book'],
#  ['electr iscariot bring summer tour elias'],
#  ['youtube tea guitar new music warrenmusic'],
#  ['documentary room adults'],
#  ['market ipantry application ready'],
#  ...]

# %% [markdown]
# --Stop words removed from 'keywords' df5 is final list--
